# %%
from joblib import load
import numpy as np

load_model = load('housing_model.joblib')

# Keep the feature order aligned with training:
# CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, TAXRM
features = np.array([[0.02729, 0.0, 7.07, 0.0, 0.469, 6.421, 78.9, 4.9671, 2.0, 242.0, 17.8, 396.90, 9.14, 242.0 / 6.421]])
prediction = load_model.predict(features)
print("Predicted MEDV:", prediction[0])
# Out:
# Predicted MEDV: 24.07799999999999
